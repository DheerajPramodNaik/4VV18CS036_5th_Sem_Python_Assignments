# %%
class student:
    
    def __init__(self, name, usn, m1, m2, m3):
        self.name = name
        self.usn = usn
        self.m1 = m1
        self.m2 = m2
        self.m3 = m3
        
    def __str__(self):
        return f"Name: {self.name} \nUSN: {self.usn} \nSubject 1 marks: {self.m1} \nSubject 2 marks: {self.m2} \nSubject 3 marks: {self.m3} \n"
    
    def increment_marks(self, bonus=10):
        self.m1 += bonus/100 * self.m1
        self.m2 += bonus/100 * self.m2
        self.m3 += bonus/100 * self.m3
        if self.m1 > 100:
            self.m1 = 100
        if self.m2 > 100:
            self.m2 = 100
        if self.m3 > 100:
            self.m3 = 100
        
    def percentage(self):
        avg = (self.m1 + self.m2 + self.m3) / 3
        print(f"Percentage: {round(avg, 2)}")

# %%
dpn = student("Dheeraj Pramod Naik", "4VV18CS036", 75, 85, 93)
print(dpn)
# Out:
# Name: Dheeraj Pramod Naik
# USN: 4VV18CS036
# Subject 1 marks: 75
# Subject 2 marks: 85
# Subject 3 marks: 93

# %%
dpn.percentage()
# Out:
# Percentage: 84.33

# %%
# Increment marks by 5%. By default the increment percentage is 10%
dpn.increment_marks(5)
print(dpn)
# Out:
# Name: Dheeraj Pramod Naik
# USN: 4VV18CS036
# Subject 1 marks: 78.75
# Subject 2 marks: 89.25
# Subject 3 marks: 97.65

# %%
dpn.increment_marks()
print(dpn)
# Out:
# Name: Dheeraj Pramod Naik
# USN: 4VV18CS036
# Subject 1 marks: 86.625
# Subject 2 marks: 98.175
# Subject 3 marks: 100

# %%
dpn.increment_marks()
print(dpn)
# Out:
# Name: Dheeraj Pramod Naik
# USN: 4VV18CS036
# Subject 1 marks: 95.2875
# Subject 2 marks: 100
# Subject 3 marks: 100

# %%
dpn.percentage()
# Out:
# Percentage: 98.43
